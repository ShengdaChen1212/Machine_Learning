# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score
pd.set_option("display.float_format", lambda x: "%.2f" % x)
df = pd.read_csv("advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0   230.10  37.80      69.20  22.10
# 1    44.50  39.30      45.10  10.40
# 2    17.20  45.90      69.30   9.30
# 3   151.50  41.30      58.50  18.50
# 4   180.80  10.80      58.40  12.90
# ..     ...    ...        ...    ...
# 195  38.20   3.70      13.80   7.60
# 196  94.20   4.90       8.10   9.70
# 197 177.00   9.30       6.40  12.80
# 198 283.60  42.00      66.20  25.50
# 199 232.10   8.60       8.70  13.40
#
# [200 rows x 4 columns]

# %%
import statsmodels.api as sm
X = df[["TV", "radio", "newspaper"]]
y = df[["sales"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
X_train = np.c_[np.ones(X_train.shape[0]), X_train] # add Intercept term
model_time1 = sm.OLS(y_train, X_train)
results_time1 = model_time1.fit()
print(results_time1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     447.7
# Date:                Wed, 01 May 2024   Prob (F-statistic):           2.12e-76
# Time:                        01:44:05   Log-Likelihood:                -315.37
# No. Observations:                 160   AIC:                             638.7
# Df Residuals:                     156   BIC:                             651.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9079      0.349      8.339      0.000       2.219       3.597
# x1             0.0468      0.002     29.312      0.000       0.044       0.050
# x2             0.1785      0.010     17.751      0.000       0.159       0.198
# x3             0.0026      0.007      0.356      0.723      -0.012       0.017
# ==============================================================================
# Omnibus:                       44.437   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.887
# Skew:                          -1.257   Prob(JB):                     3.03e-20
# Kurtosis:                       5.676   Cond. No.                         427.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = df[["TV", "radio", "newspaper"]]
y = df[["sales"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
X_train = np.c_[np.ones(X_train.shape[0]), X_train] # add Intercept term
coefficients = np.linalg.inv(X_train.T.dot(X_train)).dot(X_train.T).dot(y_train) # y_hat = b0 + b1*TV
print("Intercept:", coefficients[0])
print("Coefficient for TV:", coefficients[1], coefficients[2], coefficients[3])
# Out:
# array([[  1. ,  13.1,   0.4,  25.6],
#        [  1. ,  90.4,   0.3,  23.2],
#        [  1. ,  18.7,  12.1,  23.4],
#        [  1. , 204.1,  32.9,  46. ],
#        [  1. ,   7.3,  28.1,  41.4],
#        [  1. , 147.3,  23.9,  19.1],
#        [  1. ,  78.2,  46.8,  34.5],
#        [  1. , 228. ,  37.7,  32. ],
#        [  1. , 205. ,  45.1,  19.6],
#        [  1. , 229.5,  32.3,  74.2],
#        [  1. , 289.7,  42.3,  51.2],
#        [  1. , 123.1,  34.6,  12.4],
#        [  1. ,  19.4,  16. ,  22.3],
#        [  1. , 182.6,  46.2,  58.7],
#        [  1. , 265.6,  20. ,   0.3],
#        [  1. , 165.6,  10. ,  17.6],
#        [  1. , 218.5,   5.4,  27.4],
#        [  1. ,  25. ,  11. ,  29.7],
#        [  1. , 232.1,   8.6,   8.7],
#        [  1. ,  43. ,  25.9,  20.5],
#        [  1. , 139.2,  14.3,  25.6],
#        [  1. , 139.3,  14.5,  10.2],
#        [  1. ,   5.4,  29.9,   9.4],
#        [  1. , 293.6,  27.7,   1.8],
#        [  1. , 281.4,  39.6,  55.8],
#        [  1. ,   8.7,  48.9,  75. ],
#        [  1. ,  80.2,   0. ,   9.2],
#        [  1. , 137.9,  46.4,  59. ],
#        [  1. , 227.2,  15.8,  49.9],
#        [  1. ,  31.5,  24.6,   2.2],
#        [  1. , 262.7,  28.8,  15.9],
#        [  1. , 213.5,  43. ,  33.8],
#        [  1. , 287.6,  43. ,  71.8],
#        [  1. ,  11.7,  36.9,  45.2],
#        [  1. ,  17.9,  37.6,  21.6],
#        [  1. , 209.6,  20.6,  10.7],
#        [  1. ,  23.8,  35.1,  65.9],
#        [  1. ,  76.4,   0.8,  14.8],
#        [  1. , 250.9,  36.5,  72.3],
#        [  1. , 141.3,  26.8,  46.2],
#        [  1. , 187.8,  21.1,   9.5],
#        [  1. , 134.3,   4.9,   9.3],
#        [  1. , 239.8,   4.1,  36.9],
#        [  1. , 224. ,   2.4,  15.6],
#        [  1. ,  75.5,  10.8,   6. ],
#        [  1. ,  97.5,   7.6,   7.2],
#        [  1. ,  75.3,  20.3,  32.5],
#        [  1. ,   8.4,  27.2,   2.1],
#        [  1. , 191.1,  28.7,  18.2],
#        [  1. , 175.1,  22.5,  31.5],
#        [  1. , 135.2,  41.7,  45.9],
#        [  1. , 266.9,  43.8,   5. ],
#        [  1. ,  85.7,  35.8,  49.3],
#        [  1. , 139.5,   2.1,  26.6],
#        [  1. , 171.3,  39.7,  37.7],
#        [  1. , 187.9,  17.2,  17.9],
#        [  1. ,  38.2,   3.7,  13.8],
#        [  1. , 177. ,   9.3,   6.4],
#        [  1. ,  38. ,  40.3,  11.9],
#        [  1. , 168.4,   7.1,  12.8],
#        [  1. ,  16.9,  43.7,  89.4],
#        [  1. , 237.4,   5.1,  23.5],
#        [  1. ,  28.6,   1.5,  33. ],
#        [  1. , 197.6,  23.3,  14.2],
#        [  1. ,  17.2,  45.9,  69.3],
#        [  1. , 199.1,  30.6,  38.7],
#        [  1. , 193.2,  18.4,  65.7],
#        [  1. , 280.7,  13.9,  37. ],
#        [  1. ,  57.5,  32.8,  23.5],
#        [  1. , 175.7,  15.4,   2.4],
#        [  1. , 230.1,  37.8,  69.2],
#        [  1. ,   4.1,  11.6,   5.7],
#        [  1. , 120.5,  28.5,  14.2],
#        [  1. ,  69. ,   9.3,   0.9],
#        [  1. , 198.9,  49.4,  60. ],
#        [  1. , 206.8,   5.2,  19.4],
#        [  1. ,  88.3,  25.5,  73.4],
#        [  1. ,   0.7,  39.6,   8.7],
#        [  1. ,  89.7,   9.9,  35.7],
#        [  1. , 239.3,  15.5,  27.3],
#        [  1. , 213.4,  24.6,  13.1],
#        [  1. , 217.7,  33.5,  59. ],
#        [  1. , 243.2,  49. ,  44.3],
#        [  1. , 172.5,  18.1,  30.7],
#        [  1. , 104.6,   5.7,  34.4],
#        [  1. , 110.7,  40.6,  63.2],
#        [  1. , 156.6,   2.6,   8.3],
#        [  1. , 140.3,   1.9,   9. ],
#        [  1. , 117.2,  14.7,   5.4],
#        [  1. ,  66.1,   5.8,  24.2],
#        [  1. ,  97.2,   1.5,  30. ],
#        [  1. ,  68.4,  44.5,  35.6],
#        [  1. ,  56.2,   5.7,  29.7],
#        [  1. , 222.4,   4.3,  49.8],
#        [  1. ,  87.2,  11.8,  25.9],
#        [  1. , 228.3,  16.9,  26.2],
#        [  1. ,   7.8,  38.9,  50.6],
#        [  1. , 199.8,   2.6,  21.2],
#        [  1. ,  50. ,  11.6,  18.4],
#        [  1. , 238.2,  34.3,   5.3],
#        [  1. , 121. ,   8.4,  48.7],
#        [  1. ,  48.3,  47. ,   8.5],
#        [  1. , 241.7,  38. ,  23.2],
#        [  1. , 286. ,  13.9,   3.7],
#        [  1. , 131.1,  42.8,  28.9],
#        [  1. , 195.4,  47.7,  52.9],
#        [  1. , 177. ,  33.4,  38.7],
#        [  1. , 163.5,  36.8,   7.4],
#        [  1. , 255.4,  26.9,   5.5],
#        [  1. ,  76.4,  26.7,  22.3],
#        [  1. , 216.4,  41.7,  39.6],
#        [  1. , 142.9,  29.3,  12.6],
#        [  1. ,  27.5,   1.6,  20.7],
#        [  1. , 206.9,   8.4,  26.4],
#        [  1. ,  62.3,  12.6,  18.3],
#        [  1. , 151.5,  41.3,  58.5],
#        [  1. , 284.3,  10.6,   6.4],
#        [  1. ,  66.9,  11.7,  36.8],
#        [  1. ,  44.7,  25.8,  20.6],
#        [  1. , 265.2,   2.9,  43. ],
#        [  1. ,  39.5,  41.1,   5.8],
#        [  1. , 292.9,  28.3,  43.2],
#        [  1. ,  18.8,  21.7,  50.4],
#        [  1. ,  75.1,  35. ,  52.7],
#        [  1. , 276.9,  48.9,  41.8],
#        [  1. ,   8.6,   2.1,   1. ],
#        [  1. ,  53.5,   2. ,  21.4],
#        [  1. , 220.3,  49. ,   3.2],
#        [  1. ,  44.5,  39.3,  45.1],
#        [  1. , 136.2,  19.2,  16.6],
#        [  1. ,  13.2,  15.9,  49.6],
#        [  1. , 261.3,  42.7,  54.7],
#        [  1. , 102.7,  29.6,   8.4],
#        [  1. , 120.2,  19.6,  11.6],
#        [  1. ,  94.2,   4.9,   8.1],
#        [  1. , 193.7,  35.4,  75.6],
#        [  1. ,  76.3,  27.5,  16. ],
#        [  1. , 197.6,   3.5,   5.9],
#        [  1. , 237.4,  27.5,  11. ],
#        [  1. , 199.8,   3.1,  34.6],
#        [  1. , 220.5,  33.2,  37.9],
#        [  1. , 149.8,   1.3,  24.3],
#        [  1. ,  93.9,  43.5,  50.5],
#        [  1. , 184.9,  43.9,   1.7],
#        [  1. , 240.1,   7.3,   8.7],
#        [  1. , 296.4,  36.3, 100.9],
#        [  1. , 218.4,  27.7,  53.4],
#        [  1. , 276.7,   2.3,  23.7],
#        [  1. , 262.9,   3.5,  19.5],
#        [  1. ,  36.9,  38.6,  65.6],
#        [  1. , 109.8,  14.3,  31.7],
#        [  1. ,  59.6,  12. ,  43.1],
#        [  1. ,  96.2,  14.8,  38.9],
#        [  1. ,  17.2,   4.1,  31.6],
#        [  1. , 116. ,   7.7,  23.1],
#        [  1. , 219.8,  33.5,  45.1],
#        [  1. , 273.7,  28.9,  59.7],
#        [  1. ,  26.8,  33. ,  19.3],
#        [  1. ,  73.4,  17. ,  12.9],
#        [  1. ,  74.7,  49.4,  45.7]])
# Intercept: [2.90794702]
# Coefficient for TV: [0.0468431] [0.17854434] [0.00258619]
